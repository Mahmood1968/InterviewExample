# %%
def reverse(x ):
    rev=0
    while (x>0):
        rev=rev*10 +(x%10) 
        x=x/10
        print(rev)
    return rev

print(reverse(123))
# Out:
# 3
# 32.3
# 324.23
# 3242.4230000000002
# 32424.2423
# 324242.42423
# 3242424.242423
# 32424242.4242423
# 324242424.24242425
# 3242424242.4242425
# 32424242424.242424
# 324242424242.42426
# 3242424242424.2427
# 32424242424242.426
# 324242424242424.25
# 3242424242424242.5
# 3.2424242424242424e+16
# 3.2424242424242426e+17
# 3.2424242424242427e+18
# 3.2424242424242426e+19
# 3.2424242424242425e+20
# 3.2424242424242425e+21
# 3.2424242424242424e+22
# 3.2424242424242427e+23
# 3.2424242424242425e+24
# 3.2424242424242425e+25
# 3.242424242424243e+26
# 3.242424242424243e+27
# 3.242424242424243e+28
# 3.242424242424243e+29
# 3.242424242424243e+30
# 3.242424242424243e+31
# 3.2424242424242433e+32
# 3.2424242424242434e+33
# 3.2424242424242433e+34
# 3.2424242424242432e+35
# 3.2424242424242435e+36
# 3.2424242424242438e+37
# 3.2424242424242436e+38
# 3.2424242424242436e+39
# 3.2424242424242434e+40
# 3.2424242424242434e+41
# 3.242424242424243e+42
# 3.242424242424243e+43
# 3.242424242424243e+44
# ...

# %%
quotient = 7 // 3

# %%
print(quotient)
# Out:
# 2

# %%
print(7%3)
# Out:
# 1
